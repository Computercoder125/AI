# %% [markdown]
# <a href="https://colab.research.google.com/github/Computercoder125/AI/blob/HW4/Sean_Gor_Assignment_4_Part_3b_Stone_Game_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sean Gor
# Assignment 4 Part 3b - Leetcode problem that simulates a game of Nim (with certain constraints) and returns the winner of the game. If tie, it returns "tie"

# %% [markdown]
# ![Image 11-7-25 at 12.16 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# In Stone Game III, I used a dynamic programming approach this time, that follows the same logic as the minimax algorithm but avoids the possibly unnecessary calculations caused by recursion. The algorithm works backward through the list of stones, calculating the best possible score difference at each position by assuming both players play optimally. By storing these results in a DP array, the program more efficiently determines whether Alice, Bob, or neither has an advantage without dealing with overlapping subproblems.
