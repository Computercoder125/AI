# %% [markdown]
# Sean Gor
# Purpose: To solve the surrounded regions leetcode problem by using depth-first search

# %% [markdown]
# ![Image 9-26-25 at 5.42 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# This solution finds the regions being captured by using depth-first search. It marks every touching border with a 'T', and then those borders become an 'O', and then any visited borders withoriginally an 'O' become an 'X' since they have been captured. A copy of my code is included in the "files" section
