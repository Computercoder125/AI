# %% [markdown]
# Sean Gor
# Assignment 3 Part 4: The purpose is to solve the Minimum Cost to make at least one path valid on the grid

# %% [markdown]
# ![Image 10-21-25 at 5.16 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# I used a modified BFS to explore this grid. Each move that follows a cell’s arrow has cost 0, and changing direction has cost 1. The BFS uses a deque so that zero-cost moves are added to the front and cost-one moves to the back, showing that the search always expands cells with the smallest total cost first. This led to the overall result, namely, the minimum number of direction changes needed to reach the goal.
